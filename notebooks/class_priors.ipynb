# %%
import pandas as pd
import pickle

# %%
with open('../p01.pkl', 'rb') as f:
    pkl = pickle.load(f)

# %%
pkl
# Out:
#              participant_id video_id narration_timestamp start_timestamp  \
# narration_id
# P01_01_0                P01   P01_01        00:00:01.089     00:00:00.14
# P01_01_1                P01   P01_01        00:00:02.629     00:00:04.37
# P01_01_10               P01   P01_01        00:00:23.340     00:00:24.97
# P01_01_100              P01   P01_01        00:07:57.919     00:07:59.75
# P01_01_101              P01   P01_01        00:08:00.020     00:08:01.47
# ...                     ...      ...                 ...             ...
# P01_19_95               P01   P01_19        00:05:06.790     00:05:05.66
# P01_19_96               P01   P01_19        00:05:14.070     00:05:05.81
# P01_19_97               P01   P01_19        00:05:10.240     00:05:09.86
# P01_19_98               P01   P01_19        00:05:15.540     00:05:10.12
# P01_19_99               P01   P01_19        00:05:17.000     00:05:14.85
#
# ...

# %%
verb_class_frequencies = pkl['verb_class'].value_counts().sort_index()

# %%
verb_class_priors = verb_class_frequencies / verb_class_frequencies.sum()
verb_class_priors.index.name = 'verb_class'
verb_class_priors.name = 'prior'
# verb_class_priors.to_csv('verb_priors.csv')

# %%
verb_class_priors.reindex(list(range(0,97)),fill_value=0)

verb_class_priors
# Out:
# verb_class
# 0     0.236885
# 1     0.194591
# 2     0.103104
# 3     0.065529
# 4     0.058087
# 5     0.032674
# 6     0.024505
# 7     0.025594
# 8     0.021783
# 9     0.030496
# 10    0.032311
# 11    0.028317
# 12    0.005627
# 13    0.013796
# 14    0.017245
# 15    0.008350
# 16    0.009076
# 17    0.009076
# 18    0.005083
# 19    0.005809
# 20    0.006172
# 21    0.000908
# 22    0.006535
# 23    0.001815
# 24    0.002360
# 25    0.000363
# 27    0.004357
# 28    0.004175
# 30    0.001271
# 31    0.000726
# 32    0.006535
# 33    0.000545
# 34    0.000182
# 35    0.004357
# 36    0.000908
# 37    0.000908
# 38    0.000908
# 39    0.002178
# 41    0.003993
# 42    0.002541
# 44    0.000545
# 45    0.000182
# 47    0.001815
# 48    0.000545
# 49    0.000545
# 51    0.002541
# 52    0.003449
# 53    0.000363
# 56    0.000363
# 59    0.000182
# 60    0.002541
# 63    0.000726
# 64    0.001089
# 71    0.000363
# 72    0.002904
# 73    0.000363
# 77    0.001271
# 82    0.000182
# ...
